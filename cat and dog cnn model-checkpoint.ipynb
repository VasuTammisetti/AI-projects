# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense

# Initialising the CNN
classifier = Sequential()

# Step 1 - Convolution
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))

# Step 2 - Pooling
classifier.add(MaxPooling2D(pool_size = (2, 2)))

# Adding a second convolutional layer




# Step 3 - Flattening
classifier.add(Flatten())

# Step 4 - Full connection
classifier.add(Dense(units = 128, activation = 'relu'))

classifier.add(Dense(units = 1, activation = 'sigmoid'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Part 2 - Fitting the CNN to the images

from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)

training_set = train_datagen.flow_from_directory('C:\\Users\\vasu0\\Desktop\\lenovo data(descktop)\\MLLL\\Projects\\dogcat_new\\PetImages\\training_set\\training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')

test_set = test_datagen.flow_from_directory('C:\\Users\\vasu0\\Desktop\\lenovo data(descktop)\\MLLL\\Projects\\dogcat_new\\PetImages\\test_set\\test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')

model = classifier.fit_generator(training_set,
                         steps_per_epoch = 251,
                         epochs = 50,
                         validation_data = test_set,    
                         validation_steps = 100)

classifier.save("model.h5")
print("Saved model to disk")
# Out:
# Found 8005 images belonging to 2 classes.
# Found 2023 images belonging to 2 classes.
# Epoch 1/50
# 251/251 [==============================] - ETA: 0s - loss: 0.6728 - accuracy: 0.5981WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 100 batches). You may need to use the repeat() function when building your dataset.
# 251/251 [==============================] - 25s 100ms/step - loss: 0.6728 - accuracy: 0.5981 - val_loss: 0.6110 - val_accuracy: 0.6609
# Epoch 2/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.6010 - accuracy: 0.6763
# Epoch 3/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.5681 - accuracy: 0.7043
# Epoch 4/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.5350 - accuracy: 0.7325
# Epoch 5/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.5174 - accuracy: 0.7459
# Epoch 6/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.5034 - accuracy: 0.7502
# Epoch 7/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.4880 - accuracy: 0.7628
# Epoch 8/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.4708 - accuracy: 0.7745
# Epoch 9/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.4487 - accuracy: 0.7908
# Epoch 10/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.4484 - accuracy: 0.7819
# Epoch 11/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.4218 - accuracy: 0.8042
# Epoch 12/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.4242 - accuracy: 0.8015
# Epoch 13/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.4025 - accuracy: 0.8137
# Epoch 14/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3916 - accuracy: 0.8180
# Epoch 15/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3894 - accuracy: 0.8276
# Epoch 16/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3705 - accuracy: 0.8329
# Epoch 17/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3645 - accuracy: 0.8397
# Epoch 18/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3521 - accuracy: 0.8407
# Epoch 19/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3441 - accuracy: 0.8471
# Epoch 20/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.3259 - accuracy: 0.8561
# Epoch 21/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3270 - accuracy: 0.8595
# Epoch 22/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.3176 - accuracy: 0.8603
# Epoch 23/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.3122 - accuracy: 0.8667
# Epoch 24/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2984 - accuracy: 0.8680
# Epoch 25/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.2912 - accuracy: 0.8777
# Epoch 26/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2725 - accuracy: 0.8808
# Epoch 27/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2666 - accuracy: 0.8878
# Epoch 28/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2630 - accuracy: 0.8867
# Epoch 29/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2477 - accuracy: 0.89471s - los
# Epoch 30/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.2442 - accuracy: 0.8987
# Epoch 31/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.2377 - accuracy: 0.9019
# Epoch 32/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.2412 - accuracy: 0.8966
# Epoch 33/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.2237 - accuracy: 0.9074
# Epoch 34/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.2141 - accuracy: 0.91140s - loss: 0.2141 - accuracy:
# Epoch 35/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2079 - accuracy: 0.9148
# Epoch 36/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.1982 - accuracy: 0.9212
# Epoch 37/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.2050 - accuracy: 0.9158
# Epoch 38/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.1951 - accuracy: 0.9230
# Epoch 39/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.1915 - accuracy: 0.9240
# Epoch 40/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.1759 - accuracy: 0.9318
# Epoch 41/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.1748 - accuracy: 0.9307
# Epoch 42/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.1709 - accuracy: 0.9327
# Epoch 43/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.1734 - accuracy: 0.9292
# Epoch 44/50
# 251/251 [==============================] - 22s 89ms/step - loss: 0.1707 - accuracy: 0.9334
# Epoch 45/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.1510 - accuracy: 0.9422
# Epoch 46/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.1549 - accuracy: 0.9405
# Epoch 47/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.1458 - accuracy: 0.9417
# Epoch 48/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.1424 - accuracy: 0.9483
# Epoch 49/50
# 251/251 [==============================] - 22s 87ms/step - loss: 0.1459 - accuracy: 0.9435
# Epoch 50/50
# 251/251 [==============================] - 22s 88ms/step - loss: 0.1438 - accuracy: 0.94474s - loss: 0.138 - E
# Saved model to disk

# %%
from tensorflow import keras
model = keras.models.load_model('model.h5')

# %%
# Part 3 - Making new predictions

import numpy as np
from keras.preprocessing import image
test_image = image.load_img('c11.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = model.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
    prediction = 'dog'
    print(prediction)
    path="c11.jpg"
    display(Image.open(path))
else:
    prediction = 'cat'
    print(prediction)
    path="c11.jpg"
    display(Image.open(path))
# Out:
# cat
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=498x415 at 0x1CE2A779F70>

# %%
from IPython.display import display
from PIL import Image

# %%
path="d11.jpg"
display(Image.open(path))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=426x480 at 0x1CE2A9BCFA0>
